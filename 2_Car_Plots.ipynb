# %%
#Import the required librarys 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#load data
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-39146e81-39bf-403a-af69-9a682fcfe3d7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39146e81-39bf-403a-af69-9a682fcfe3d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2_car_procesed.csv to 2_car_procesed.csv

# %%
df= pd.read_csv('2_car_procesed.csv')
df.head(5)
# Out:
#    Unnamed: 0   ID  ... Navigation_System Rain_Sensing_Wipers
# 0           1  1.0  ...                NO                  NO
# 1           2  2.0  ...                NO                  NO
# 2           3  3.0  ...                NO                  NO
# 3           4  4.0  ...                NO                  NO
# 4           5  5.0  ...                NO                  NO
#
# [5 rows x 36 columns]

# %%
print(df.columns.values.tolist())
# Out:
# ['Unnamed: 0', 'ID', 'Make', 'Model', 'Price', 'Valves_Per_Cylinder', 'Emission_Norm', 'Fuel_Type', 'Fuel_Tank_Capacity', 'Height', 'Width', 'Doors', 'City_Mileage', 'Front_Brakes', 'Rear_Brakes', 'Front_Suspension', 'Rear_Suspension', 'Power_Steering', 'Power_Windows', 'Power_Seats', 'Keyless_Entry', 'Power', 'Torque', 'Seating_Capacity', 'Audiosystem', 'Basic_Warranty', 'Central_Locking', 'Cup_Holders', 'Minimum_Turning_Radius', 'Drive_Modes', 'Voice_Recognition', 'ABS_(Anti-lock_Braking_System)', 'Parking_Assistance', 'EBA_(Electronic_Brake_Assist)', 'Navigation_System', 'Rain_Sensing_Wipers']

# %%
#Heatmap for correlation
plt.figure(figsize = (10, 7)) 

sns.heatmap(df.corr(), annot=True, annot_kws={'size': 10})

# %%
#The fuel tank capacity Average from all cars  is 40 Litters 
df["Fuel_Tank_Capacity"].plot.hist()

# %%
df["Doors"].plot.hist()

# %%
df["Seating_Capacity"].plot.hist()

# %%
df["Valves_Per_Cylinder"].plot.hist()

# %%
sns.countplot(x='Emission_Norm',data=df)

# %%
sns.countplot(x='Rain_Sensing_Wipers',data=df)

# %%
fig, ax = plt.subplots(figsize = (15,5))
plt1 = sns.countplot(df['Make'], order=pd.value_counts(df['Make']).index,)
plt1.set(xlabel = 'Make', ylabel= 'Count of Cars')

plt.show()
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(x="City_Mileage", y="Make", data=df)

# %%
sns.boxplot(x="Doors", y="Make", data=df)

# %%
sns.boxplot(x="Fuel_Tank_Capacity", y="Make", data=df)

# %%
#Power_Steering
fig, ax = plt.subplots(figsize = (7,5))
plt1 = sns.countplot(df['Power_Steering'], order=pd.value_counts(df['Power_Steering']).index,)
plt1.set(xlabel = 'Power_Steering', ylabel= 'Count of Cars')
plt.show()
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Seating_Capacity
fig, ax = plt.subplots(figsize = (7,5))
plt1 = sns.countplot(df['Seating_Capacity'], order=pd.value_counts(df['Seating_Capacity']).index,)
plt1.set(xlabel = 'Seating_Capacity', ylabel= 'Count of Cars')

plt.show()
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Audiosystem
fig, ax = plt.subplots(figsize = (25,5))
plt1 = sns.countplot(df['Audiosystem'], order=pd.value_counts(df['Audiosystem']).index,)
plt1.set(xlabel = 'Audiosystem', ylabel= 'Count of Cars')

plt.show()
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Basic_Warranty
fig, ax = plt.subplots(figsize = (25,5))
plt1 = sns.countplot(df['Basic_Warranty'], order=pd.value_counts(df['Basic_Warranty']).index,)
plt1.set(xlabel = 'Basic_Warranty', ylabel= 'Count of Cars')
plt.show()
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig, ax = plt.subplots(figsize = (10,5))
plt1 = sns.countplot(df['Valves_Per_Cylinder'], order=pd.value_counts(df['Valves_Per_Cylinder']).index,)
plt1.set(xlabel = 'Valves_Per_Cylinder', ylabel= 'Count of Cars')

plt.show()
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# 
df_comp_avg_price = df[['Keyless_Entry','Price']].groupby("Keyless_Entry", as_index = False).mean().rename(columns={'Price':'Keyless_Entry '})
plt1 = df_comp_avg_price.plot(x = 'Keyless_Entry', kind='bar',legend = False, sort_columns = True, figsize = (15,5))
plt1.set_xlabel("Keyless_Entry ")
plt1.set_ylabel("Avg Price (INR)")
plt.show()

# %%
df_comp_avg_price = df[['Drive_Modes','Price']].groupby("Drive_Modes", as_index = False).mean().rename(columns={'Price':'Drive_Modes '})
plt1 = df_comp_avg_price.plot(x = 'Drive_Modes', kind='bar',legend = False, sort_columns = True, figsize = (15,5))
plt1.set_xlabel(" Drive_Modes")
plt1.set_ylabel("Avg Price (INR)")
plt.show()

# %%
df_drivewheel_avg_price = df[['Power_Steering','Price']].groupby("Power_Steering", as_index = False).mean().rename(columns={'Price':'drivewheel_avg_price'})
plt1 = df_drivewheel_avg_price.plot(x = 'Power_Steering', kind='bar', sort_columns = True,legend = False,)
plt1.set_xlabel("Drive Wheel Type")
plt1.set_ylabel("Avg Price (Dollars)")

plt.show()

# %%
#Parking_Assistance
df_PK_avg_price = df[['Parking_Assistance','Price']].groupby("Parking_Assistance", as_index = False).mean().rename(columns={'Price':'En'})
plt1 = df_PK_avg_price.plot(x = 'Parking_Assistance', kind='bar', sort_columns = True,legend = False,)
plt1.set_xlabel("Parking_Assistance")
plt1.set_ylabel("Avg Price INR Lakh 0.1 = 1Lakh")
plt.show()

# %%
#Minimum_Turning_Radius
df_PK_avg_price = df[['Minimum_Turning_Radius','Price']].groupby("Minimum_Turning_Radius", as_index = False).mean().rename(columns={'Price':'En'})
plt1 = df_PK_avg_price.plot(x = 'Minimum_Turning_Radius', kind='bar', sort_columns = True,legend = False,)
plt1.set_xlabel("Minimum_Turning_Radius")
plt1.set_ylabel("Avg Price INR Lakh 0.1 = 1Lakh")
plt.show()

# %%
#Parking_Assistance
df_RW_avg_price = df[['Rain_Sensing_Wipers','Price']].groupby("Rain_Sensing_Wipers", as_index = False).mean().rename(columns={'Price':''})
plt1 = df_RW_avg_price.plot(x = 'Rain_Sensing_Wipers', kind='bar', sort_columns = True,legend = False,)
plt1.set_xlabel("Rain_Sensing_Wipers")
plt1.set_ylabel("Avg Price INR Lakh 0.1 = 1Lakh")
plt.show()

# %%
df_R_avg_price = df[['Navigation_System','Price']].groupby("Navigation_System", as_index = False).mean().rename(columns={'Price':''})
plt1 = df_R_avg_price.plot(x = 'Navigation_System', kind='bar', sort_columns = True,legend = False,)
plt1.set_xlabel("Navigation_System")
plt1.set_ylabel("Avg Price INR Lakh 0.1 = 10Lakh")
plt.show()

# %%
#EBA_(Electronic_Brake_Assist)
df_R_avg_price = df[['EBA_(Electronic_Brake_Assist)','Price']].groupby("EBA_(Electronic_Brake_Assist)", as_index = False).mean().rename(columns={'Price':''})
plt1 = df_R_avg_price.plot(x = 'EBA_(Electronic_Brake_Assist)', kind='bar', sort_columns = True,legend = False,)
plt1.set_xlabel("EBA_(Electronic_Brake_Assist)")
plt1.set_ylabel("Avg Price INR Lakh 0.1 = 10Lakh")
plt.show()

# %%
df_Eng_avg_price = df[['Emission_Norm','Price']].groupby("Emission_Norm", as_index = False).mean().rename(columns={'Price':'En'})
plt1 = df_Eng_avg_price.plot(x = 'Emission_Norm', kind='bar', sort_columns = True,legend = False,)
plt1.set_xlabel("Emission_Norm")
plt1.set_ylabel("Avg Price INR Lakh 0.1 = 1Lakh")
plt.show()

# %%
df_Power_avg_price = df[['Power','Price']].groupby("Power", as_index = False).mean().rename(columns={'Price':''})
plt1 = df_Power_avg_price.plot(x = 'Power', kind='bar', sort_columns = True,legend = False,figsize = (15,5))
plt1.set_xlabel("Power")
plt1.set_ylabel("Avg Price INR Lakh 0.1 = 1Lakh")

plt.show()

# %%
df_Warranty_avg_price = df[['Basic_Warranty','Price']].groupby("Basic_Warranty", as_index = False).mean().rename(columns={'Price':''})
plt1 = df_Warranty_avg_price.plot(x = 'Basic_Warranty', kind='bar', sort_columns = True,legend = False,figsize = (15,5))
plt1.set_xlabel("Basic_Warranty")
plt1.set_ylabel("Avg Price INR Lakh 0.1 = 1Lakh")

plt.show()

# %%
df_Parking_avg_price = df[['Parking_Assistance','Price']].groupby("Parking_Assistance", as_index = False).mean().rename(columns={'Price':''})
plt1 = df_Parking_avg_price.plot(x = 'Parking_Assistance', kind='bar', sort_columns = True,legend = False,figsize = (15,5))
plt1.set_xlabel("Parking_Assistance")
plt1.set_ylabel("Avg Price INR Lakh 0.1 = 1Lakh")

plt.show()

# %%
df_Turning_avg_price = df[['Minimum_Turning_Radius','Price']].groupby("Minimum_Turning_Radius", as_index = False).mean().rename(columns={'Price':''})
plt1 = df_Turning_avg_price.plot(x = 'Minimum_Turning_Radius', kind='bar', sort_columns = True,legend = False,figsize = (15,5))
plt1.set_xlabel("Minimum_Turning_Radius")
plt1.set_ylabel("Avg Price INR Lakh 0.1 = 1Lakh")

plt.show()

# %%
#Rear_Suspension 	
df_Suspension_avg_price = df[['Rear_Suspension','Price']].groupby("Rear_Suspension", as_index = False).mean().rename(columns={'Price':''})
plt1 = df_Suspension_avg_price.plot(x = 'Rear_Suspension', kind='bar', sort_columns = True,legend = False,figsize = (15,5))
plt1.set_xlabel("Rear_Suspension")
plt1.set_ylabel("Avg Price INR Lakh 0.1 = 1Lakh")

plt.show()

# %%
#Fuel_Tank_Capacity
df_Capacity_avg_price = df[['Fuel_Tank_Capacity','Price']].groupby("Fuel_Tank_Capacity", as_index = False).mean().rename(columns={'Price':''})
plt1 = df_Capacity_avg_price.plot(x = 'Fuel_Tank_Capacity', kind='bar', sort_columns = True,legend = False,figsize = (15,5))
plt1.set_xlabel("Fuel_Tank_Capacity")
plt1.set_ylabel("Avg Price INR Lakh 0.1 = 1Lakh")

plt.show()

# %%
fig, axs = plt.subplots(2,figsize=(15,10))
plt1 = sns.scatterplot(x = 'Height', y = 'Price', data = df, ax = axs[1])
plt1.set_xlabel('Height (Inches)')
plt1.set_ylabel('Price of Car in INR Lakh')
plt2 = sns.scatterplot(x = 'Width', y = 'Price', data = df, ax = axs[0])
plt2.set_xlabel('Width of Car (Inches)')
plt2.set_ylabel('Price of Car in INR Lakh')
plt.tight_layout()

# %%
plt.figure(figsize=(10, 8))
sns.pairplot(auto)
plt.show()
